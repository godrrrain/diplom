# %%
import syft as sy
sy.requires(">=0.8-beta")
# Out:
# ✅ The installed version of syft==0.8.0 matches the requirement >=0.8b0

# %%
import syft as sy
sy.requires(">=0.8-beta")
domain = sy.login(port=8081)
# Out:
# ✅ The installed version of syft==0.8.0 matches the requirement >=0.8b0

# %%
domain.api
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 domain.api
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/client/client.py:350, in SyftClient.api(self)
#     347 @property
#     348 def api(self) -> SyftAPI:
#     349     if self._api is None:
# --> 350         self._fetch_api(self.credentials)
#     352     return self._api
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/client/client.py:520, in SyftClient._fetch_api(self, credentials)
#     519 def _fetch_api(self, credentials: SyftSigningKey):
# --> 520     _api: SyftAPI = self.connection.get_api(credentials=credentials)
#     522     def refresh_callback():
#     523         return self._fetch_api(self.credentials)
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/client/client.py:176, in HTTPConnection.get_api(self, credentials)
#     175 def get_api(self, credentials: SyftSigningKey) -> SyftAPI:
# --> 176     params = {"verify_key": str(credentials.verify_key)}
#     177     content = self._make_get(self.routes.ROUTE_API.value, params=params)
#     178     obj = _deserialize(content, from_bytes=True)
#
# AttributeError: 'NoneType' object has no attribute 'verify_key'

# %%
# run this cell
domain_client = sy.login(
    port=8081,
    email="info@openmined.org",
    password="changethis"
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 # run this cell
# ----> 2 domain_client = sy.login(
#       3     port=8081,
#       4     email="info@openmined.org",
#       5     password="changethis"
#       6 )
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/client/client.py:576, in login(url, node, port, email, password, cache)
#     573         _client = _client_cache
#     575 if not _client.authed and login_credentials:
# --> 576     _client.login(
#     577         email=login_credentials.email,
#     578         password=login_credentials.password,
#     579         cache=cache,
#     580     )
#     581     if _client.authed:
#     582         print(f"Logged into {_client.name} as <{login_credentials.email}>")
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/client/client.py:434, in SyftClient.login(self, email, password, cache)
#     432 if signing_key is not None:
#     433     self.credentials = signing_key
# --> 434     self._fetch_api(self.credentials)
#     435     if cache:
#     436         SyftClientSessionCache.add_client(
#     437             email=email,
#     438             password=password,
#     439             connection=self.connection,
#     440             syft_client=self,
#     441         )
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/client/client.py:520, in SyftClient._fetch_api(self, credentials)
#     519 def _fetch_api(self, credentials: SyftSigningKey):
# --> 520     _api: SyftAPI = self.connection.get_api(credentials=credentials)
#     522     def refresh_callback():
#     523         return self._fetch_api(self.credentials)
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/client/client.py:178, in HTTPConnection.get_api(self, credentials)
#     176 params = {"verify_key": str(credentials.verify_key)}
#     177 content = self._make_get(self.routes.ROUTE_API.value, params=params)
# --> 178 obj = _deserialize(content, from_bytes=True)
#     179 obj.connection = self
#     180 obj.signing_key = credentials
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/deserialize.py:29, in _deserialize(blob, from_proto, from_bytes)
#      26     raise TypeError("Wrong deserialization format.")
#      28 if from_bytes:
# ---> 29     return rs_bytes2object(blob)
#      31 if from_proto:
#      32     return rs_proto2object(blob)
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/recursive.py:184, in rs_bytes2object(blob)
#     179 MAX_TRAVERSAL_LIMIT = 2**64 - 1
#     181 with recursive_scheme.from_bytes(  # type: ignore
#     182     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#     183 ) as msg:
# --> 184     return rs_proto2object(msg)
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/recursive.py:247, in rs_proto2object(proto)
#     245 for attr_name, attr_bytes_list in zip(proto.fieldsName, proto.fieldsData):
#     246     attr_bytes = combine_bytes(attr_bytes_list)
# --> 247     attr_value = _deserialize(attr_bytes, from_bytes=True)
#     248     transforms = serde_overrides.get(attr_name, None)
#     250     if transforms is not None:
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/deserialize.py:29, in _deserialize(blob, from_proto, from_bytes)
#      26     raise TypeError("Wrong deserialization format.")
#      28 if from_bytes:
# ---> 29     return rs_bytes2object(blob)
#      31 if from_proto:
#      32     return rs_proto2object(blob)
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/recursive.py:184, in rs_bytes2object(blob)
#     179 MAX_TRAVERSAL_LIMIT = 2**64 - 1
#     181 with recursive_scheme.from_bytes(  # type: ignore
#     182     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#     183 ) as msg:
# --> 184     return rs_proto2object(msg)
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/recursive.py:241, in rs_proto2object(proto)
#     236     if deserialize is None:
#     237         raise Exception(
#     238             f"Cant serialize {type(proto)} nonrecursive without serialize."
#     239         )
# --> 241     return deserialize(combine_bytes(proto.nonrecursiveBlob))
#     243 kwargs = {}
#     245 for attr_name, attr_bytes_list in zip(proto.fieldsName, proto.fieldsData):
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/recursive_primitives.py:107, in deserialize_kv(mapping_type, blob)
#     106 def deserialize_kv(mapping_type: type, blob: bytes) -> Mapping:
# --> 107     pairs = get_deserialized_kv_pairs(blob=blob)
#     108     return mapping_type(pairs)
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/recursive_primitives.py:100, in get_deserialized_kv_pairs(blob)
#      93 with kv_iterable_schema.from_bytes(  # type: ignore
#      94     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#      95 ) as msg:
#      96     for key, value in zip(msg.keys, msg.values):
#      97         pairs.append(
#      98             (
#      99                 _deserialize(key, from_bytes=True),
# --> 100                 _deserialize(combine_bytes(value), from_bytes=True),
#     101             )
#     102         )
#     103 return pairs
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/deserialize.py:29, in _deserialize(blob, from_proto, from_bytes)
#      26     raise TypeError("Wrong deserialization format.")
#      28 if from_bytes:
# ---> 29     return rs_bytes2object(blob)
#      31 if from_proto:
#      32     return rs_proto2object(blob)
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/recursive.py:184, in rs_bytes2object(blob)
#     179 MAX_TRAVERSAL_LIMIT = 2**64 - 1
#     181 with recursive_scheme.from_bytes(  # type: ignore
#     182     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#     183 ) as msg:
# --> 184     return rs_proto2object(msg)
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/recursive.py:247, in rs_proto2object(proto)
#     245 for attr_name, attr_bytes_list in zip(proto.fieldsName, proto.fieldsData):
#     246     attr_bytes = combine_bytes(attr_bytes_list)
# --> 247     attr_value = _deserialize(attr_bytes, from_bytes=True)
#     248     transforms = serde_overrides.get(attr_name, None)
#     250     if transforms is not None:
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/deserialize.py:29, in _deserialize(blob, from_proto, from_bytes)
#      26     raise TypeError("Wrong deserialization format.")
#      28 if from_bytes:
# ---> 29     return rs_bytes2object(blob)
#      31 if from_proto:
#      32     return rs_proto2object(blob)
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/recursive.py:184, in rs_bytes2object(blob)
#     179 MAX_TRAVERSAL_LIMIT = 2**64 - 1
#     181 with recursive_scheme.from_bytes(  # type: ignore
#     182     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#     183 ) as msg:
# --> 184     return rs_proto2object(msg)
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/recursive.py:241, in rs_proto2object(proto)
#     236     if deserialize is None:
#     237         raise Exception(
#     238             f"Cant serialize {type(proto)} nonrecursive without serialize."
#     239         )
# --> 241     return deserialize(combine_bytes(proto.nonrecursiveBlob))
#     243 kwargs = {}
#     245 for attr_name, attr_bytes_list in zip(proto.fieldsName, proto.fieldsData):
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/signature.py:52, in deserialize_signature(blob)
#      51 def deserialize_signature(blob: bytes) -> Signature:
# ---> 52     obj_dict = _deserialize(blob, from_bytes=True)
#      53     return Signature(**obj_dict)
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/deserialize.py:29, in _deserialize(blob, from_proto, from_bytes)
#      26     raise TypeError("Wrong deserialization format.")
#      28 if from_bytes:
# ---> 29     return rs_bytes2object(blob)
#      31 if from_proto:
#      32     return rs_proto2object(blob)
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/recursive.py:184, in rs_bytes2object(blob)
#     179 MAX_TRAVERSAL_LIMIT = 2**64 - 1
#     181 with recursive_scheme.from_bytes(  # type: ignore
#     182     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#     183 ) as msg:
# --> 184     return rs_proto2object(msg)
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/recursive.py:241, in rs_proto2object(proto)
#     236     if deserialize is None:
#     237         raise Exception(
#     238             f"Cant serialize {type(proto)} nonrecursive without serialize."
#     239         )
# --> 241     return deserialize(combine_bytes(proto.nonrecursiveBlob))
#     243 kwargs = {}
#     245 for attr_name, attr_bytes_list in zip(proto.fieldsName, proto.fieldsData):
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/recursive_primitives.py:107, in deserialize_kv(mapping_type, blob)
#     106 def deserialize_kv(mapping_type: type, blob: bytes) -> Mapping:
# --> 107     pairs = get_deserialized_kv_pairs(blob=blob)
#     108     return mapping_type(pairs)
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/recursive_primitives.py:100, in get_deserialized_kv_pairs(blob)
#      93 with kv_iterable_schema.from_bytes(  # type: ignore
#      94     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#      95 ) as msg:
#      96     for key, value in zip(msg.keys, msg.values):
#      97         pairs.append(
#      98             (
#      99                 _deserialize(key, from_bytes=True),
# --> 100                 _deserialize(combine_bytes(value), from_bytes=True),
#     101             )
#     102         )
#     103 return pairs
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/deserialize.py:29, in _deserialize(blob, from_proto, from_bytes)
#      26     raise TypeError("Wrong deserialization format.")
#      28 if from_bytes:
# ---> 29     return rs_bytes2object(blob)
#      31 if from_proto:
#      32     return rs_proto2object(blob)
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/recursive.py:184, in rs_bytes2object(blob)
#     179 MAX_TRAVERSAL_LIMIT = 2**64 - 1
#     181 with recursive_scheme.from_bytes(  # type: ignore
#     182     blob, traversal_limit_in_words=MAX_TRAVERSAL_LIMIT
#     183 ) as msg:
# --> 184     return rs_proto2object(msg)
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/site-packages/syft/serde/recursive.py:275, in rs_proto2object(proto)
#     273     obj = class_type.__new__(class_type)  # type: ignore
#     274     for attr_name, attr_value in kwargs.items():
# --> 275         setattr(obj, attr_name, attr_value)
#     277 return obj
#
# File ~/anaconda3/envs/syft_env/lib/python3.9/typing.py:717, in _BaseGenericAlias.__setattr__(self, attr, val)
#     715     super().__setattr__(attr, val)
#     716 else:
# --> 717     setattr(self.__origin__, attr, val)
#
# AttributeError: '_SpecialForm' object has no attribute '_paramspec_tvars'
